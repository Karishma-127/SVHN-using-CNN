# %%
import tensorflow as tf
import numpy as np
import keras
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from time import time
# %matplotlib inline

# %%
# Set random state

np.random.seed(20)

# %%
# Load the data

train_raw = loadmat('/content/sample_data/train_32x32.mat')
test_raw = loadmat('/content/sample_data/test_32x32.mat')

# %%
# Load images and labels

train_images = np.array(train_raw['X'])
test_images = np.array(test_raw['X'])

train_labels = train_raw['y']
test_labels = test_raw['y']

# %%
train_images = np.moveaxis(train_images, -1, 0)
test_images = np.moveaxis(test_images, -1, 0)

print(train_images.shape)
print(test_images.shape)
# Out:
# (73257, 32, 32, 3)
# (26032, 32, 32, 3)

# %%
# Plot a random image and its label

plt.imshow(train_images[13000])
plt.show()

print('Label: ', train_labels[13000])
# Out:
# Label:  [4]

# %%
# Convert train and test images into 'float64' type

train_images = train_images.astype('float64')
test_images = test_images.astype('float64')

# %%
# Convert train and test labels into 'int64' type

train_labels = train_labels.astype('int64')
test_labels = test_labels.astype('int64')

# %%
# Normalize the images data

print('Min: {}, Max: {}'.format(train_images.min(), train_images.max()))

train_images /= 255.0
test_images /= 255.0
# Out:
# Min: 0.0, Max: 255.0

# %%
# One-hot encoding of train and test labels

lb = LabelBinarizer()
train_labels = lb.fit_transform(train_labels)
test_labels = lb.fit_transform(test_labels)

# %%
# Split train data into train and validation sets

X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels,
                                                  test_size=0.15, random_state=22)

# %%
X_train = X_train[:73000,:,:,:]
y_train = y_train[:73000]

X_val = X_val[:10000,:,:,:]
y_val = y_val[:10000]

# %%
# Data augmentation (CNN Layer)

datagen = ImageDataGenerator(rotation_range=8,
                             zoom_range=[0.95, 1.05],
                             height_shift_range=0.10,
                             shear_range=0.15)

# %%
# Define actual model

keras.backend.clear_session()

model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding='same', 
                           activation='relu',
                           input_shape=(32, 32, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(64, (5, 5), padding='same', 
                           activation='relu',
                           input_shape=(32, 32, 3)),
    keras.layers.BatchNormalization(),               
    keras.layers.MaxPooling2D((2, 2)),

    
    keras.layers.Conv2D(128, (5, 5), padding='same', 
                           activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(512, (5, 5), padding='same', 
                           activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Dropout(0.3),
    
    keras.layers.Flatten(),
    keras.layers.Dense(1000, activation='relu'),
    keras.layers.Dropout(0.4),    
    keras.layers.Dense(10,  activation='softmax')
])

early_stopping = keras.callbacks.EarlyStopping(monitor='loss', patience=8)
optimizer = keras.optimizers.Adam(lr=1e-3, amsgrad=True)
model_checkpoint = keras.callbacks.ModelCheckpoint(
                   '/content/sample_data/best_cnn.h5', 
                   save_best_only=True)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy', tf.keras.metrics.CategoricalAccuracy(), 
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tf.keras.metrics.MeanSquaredError(),
                       tf.keras.metrics.CosineSimilarity(axis=1),
                       tf.keras.metrics.CategoricalCrossentropy()
                       ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1638912
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              2049000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 3,959,490
# Trainable params: 3,958,018
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# Fit model in order to make predictions
start = time()
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=128),
                              epochs=30, validation_data=(X_val, y_val),
                              callbacks=[early_stopping, model_checkpoint])
end = time()
end = end - start
print('Time taken to train the data: {:.3f} seconds'.format(end))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 487/487 [==============================] - 804s 2s/step - loss: 2.3456 - accuracy: 0.3552 - categorical_accuracy: 0.3552 - precision: 0.5509 - recall: 0.2182 - mean_squared_error: 0.0787 - cosine_similarity: 0.4504 - categorical_crossentropy: 2.3456 - val_loss: 0.6786 - val_accuracy: 0.8024 - val_categorical_accuracy: 0.8024 - val_precision: 0.9473 - val_recall: 0.6566 - val_mean_squared_error: 0.0293 - val_cosine_similarity: 0.8222 - val_categorical_crossentropy: 0.6786
# Epoch 2/30
# 487/487 [==============================] - 778s 2s/step - loss: 0.4962 - accuracy: 0.8488 - categorical_accuracy: 0.8488 - precision: 0.9104 - recall: 0.8046 - mean_squared_error: 0.0216 - cosine_similarity: 0.8691 - categorical_crossentropy: 0.4962 - val_loss: 0.3328 - val_accuracy: 0.9025 - val_categorical_accuracy: 0.9025 - val_precision: 0.9407 - val_recall: 0.8754 - val_mean_squared_error: 0.0141 - val_cosine_similarity: 0.9158 - val_categorical_crossentropy: 0.3328
# Epoch 3/30
# 487/487 [==============================] - 758s 2s/step - loss: 0.3741 - accuracy: 0.8879 - categorical_accuracy: 0.8879 - precision: 0.9307 - recall: 0.8551 - mean_squared_error: 0.0161 - cosine_similarity: 0.9032 - categorical_crossentropy: 0.3741 - val_loss: 0.3395 - val_accuracy: 0.9017 - val_categorical_accuracy: 0.9017 - val_precision: 0.9436 - val_recall: 0.8654 - val_mean_squared_error: 0.0145 - val_cosine_similarity: 0.9139 - val_categorical_crossentropy: 0.3395
# Epoch 4/30
# 487/487 [==============================] - 754s 2s/step - loss: 0.3143 - accuracy: 0.9059 - categorical_accuracy: 0.9059 - precision: 0.9406 - recall: 0.8796 - mean_squared_error: 0.0136 - cosine_similarity: 0.9190 - categorical_crossentropy: 0.3143 - val_loss: 0.2740 - val_accuracy: 0.9215 - val_categorical_accuracy: 0.9215 - val_precision: 0.9497 - val_recall: 0.9009 - val_mean_squared_error: 0.0115 - val_cosine_similarity: 0.9317 - val_categorical_crossentropy: 0.2740
# Epoch 5/30
# 487/487 [==============================] - 749s 2s/step - loss: 0.2807 - accuracy: 0.9179 - categorical_accuracy: 0.9179 - precision: 0.9468 - recall: 0.8949 - mean_squared_error: 0.0120 - cosine_similarity: 0.9290 - categorical_crossentropy: 0.2807 - val_loss: 0.2718 - val_accuracy: 0.9244 - val_categorical_accuracy: 0.9244 - val_precision: 0.9505 - val_recall: 0.9046 - val_mean_squared_error: 0.0112 - val_cosine_similarity: 0.9341 - val_categorical_crossentropy: 0.2718
# Epoch 6/30
# 487/487 [==============================] - 745s 2s/step - loss: 0.2487 - accuracy: 0.9286 - categorical_accuracy: 0.9286 - precision: 0.9531 - recall: 0.9079 - mean_squared_error: 0.0107 - cosine_similarity: 0.9375 - categorical_crossentropy: 0.2487 - val_loss: 0.3502 - val_accuracy: 0.8970 - val_categorical_accuracy: 0.8970 - val_precision: 0.9376 - val_recall: 0.8669 - val_mean_squared_error: 0.0146 - val_cosine_similarity: 0.9112 - val_categorical_crossentropy: 0.3502
# Epoch 7/30
# 487/487 [==============================] - 774s 2s/step - loss: 0.2376 - accuracy: 0.9299 - categorical_accuracy: 0.9299 - precision: 0.9533 - recall: 0.9128 - mean_squared_error: 0.0103 - cosine_similarity: 0.9397 - categorical_crossentropy: 0.2376 - val_loss: 0.2428 - val_accuracy: 0.9327 - val_categorical_accuracy: 0.9327 - val_precision: 0.9562 - val_recall: 0.9182 - val_mean_squared_error: 0.0098 - val_cosine_similarity: 0.9423 - val_categorical_crossentropy: 0.2428
# Epoch 8/30
# 487/487 [==============================] - 775s 2s/step - loss: 0.2187 - accuracy: 0.9366 - categorical_accuracy: 0.9366 - precision: 0.9570 - recall: 0.9205 - mean_squared_error: 0.0094 - cosine_similarity: 0.9453 - categorical_crossentropy: 0.2187 - val_loss: 0.2786 - val_accuracy: 0.9211 - val_categorical_accuracy: 0.9211 - val_precision: 0.9477 - val_recall: 0.9045 - val_mean_squared_error: 0.0116 - val_cosine_similarity: 0.9313 - val_categorical_crossentropy: 0.2786
# Epoch 9/30
# 487/487 [==============================] - 787s 2s/step - loss: 0.1901 - accuracy: 0.9436 - categorical_accuracy: 0.9436 - precision: 0.9599 - recall: 0.9306 - mean_squared_error: 0.0083 - cosine_similarity: 0.9519 - categorical_crossentropy: 0.1901 - val_loss: 0.2364 - val_accuracy: 0.9365 - val_categorical_accuracy: 0.9365 - val_precision: 0.9565 - val_recall: 0.9256 - val_mean_squared_error: 0.0095 - val_cosine_similarity: 0.9444 - val_categorical_crossentropy: 0.2364
# Epoch 10/30
# 487/487 [==============================] - 774s 2s/step - loss: 0.1755 - accuracy: 0.9475 - categorical_accuracy: 0.9475 - precision: 0.9628 - recall: 0.9353 - mean_squared_error: 0.0078 - cosine_similarity: 0.9548 - categorical_crossentropy: 0.1755 - val_loss: 0.2453 - val_accuracy: 0.9354 - val_categorical_accuracy: 0.9354 - val_precision: 0.9534 - val_recall: 0.9242 - val_mean_squared_error: 0.0095 - val_cosine_similarity: 0.9439 - val_categorical_crossentropy: 0.2453
# Epoch 11/30
# 487/487 [==============================] - 782s 2s/step - loss: 0.1675 - accuracy: 0.9503 - categorical_accuracy: 0.9503 - precision: 0.9647 - recall: 0.9392 - mean_squared_error: 0.0074 - cosine_similarity: 0.9573 - categorical_crossentropy: 0.1675 - val_loss: 0.2511 - val_accuracy: 0.9346 - val_categorical_accuracy: 0.9346 - val_precision: 0.9563 - val_recall: 0.9169 - val_mean_squared_error: 0.0100 - val_cosine_similarity: 0.9418 - val_categorical_crossentropy: 0.2511
# Epoch 12/30
# 487/487 [==============================] - 769s 2s/step - loss: 0.1504 - accuracy: 0.9552 - categorical_accuracy: 0.9552 - precision: 0.9671 - recall: 0.9454 - mean_squared_error: 0.0067 - cosine_similarity: 0.9614 - categorical_crossentropy: 0.1504 - val_loss: 0.2453 - val_accuracy: 0.9341 - val_categorical_accuracy: 0.9341 - val_precision: 0.9519 - val_recall: 0.9232 - val_mean_squared_error: 0.0096 - val_cosine_similarity: 0.9431 - val_categorical_crossentropy: 0.2453
# Epoch 13/30
# 487/487 [==============================] - 754s 2s/step - loss: 0.1425 - accuracy: 0.9568 - categorical_accuracy: 0.9568 - precision: 0.9685 - recall: 0.9473 - mean_squared_error: 0.0064 - cosine_similarity: 0.9630 - categorical_crossentropy: 0.1425 - val_loss: 0.2574 - val_accuracy: 0.9316 - val_categorical_accuracy: 0.9316 - val_precision: 0.9509 - val_recall: 0.9208 - val_mean_squared_error: 0.0099 - val_cosine_similarity: 0.9416 - val_categorical_crossentropy: 0.2574
# Epoch 14/30
# 487/487 [==============================] - 750s 2s/step - loss: 0.1279 - accuracy: 0.9610 - categorical_accuracy: 0.9610 - precision: 0.9714 - recall: 0.9532 - mean_squared_error: 0.0059 - cosine_similarity: 0.9665 - categorical_crossentropy: 0.1279 - val_loss: 0.2638 - val_accuracy: 0.9342 - val_categorical_accuracy: 0.9342 - val_precision: 0.9484 - val_recall: 0.9249 - val_mean_squared_error: 0.0100 - val_cosine_similarity: 0.9418 - val_categorical_crossentropy: 0.2638
# Epoch 15/30
# 487/487 [==============================] - 749s 2s/step - loss: 0.1163 - accuracy: 0.9638 - categorical_accuracy: 0.9638 - precision: 0.9725 - recall: 0.9572 - mean_squared_error: 0.0054 - cosine_similarity: 0.9693 - categorical_crossentropy: 0.1163 - val_loss: 0.2956 - val_accuracy: 0.9223 - val_categorical_accuracy: 0.9223 - val_precision: 0.9387 - val_recall: 0.9122 - val_mean_squared_error: 0.0116 - val_cosine_similarity: 0.9322 - val_categorical_crossentropy: 0.2956
# Epoch 16/30
# 487/487 [==============================] - 754s 2s/step - loss: 0.1082 - accuracy: 0.9664 - categorical_accuracy: 0.9664 - precision: 0.9731 - recall: 0.9606 - mean_squared_error: 0.0051 - cosine_similarity: 0.9714 - categorical_crossentropy: 0.1082 - val_loss: 0.2626 - val_accuracy: 0.9337 - val_categorical_accuracy: 0.9337 - val_precision: 0.9509 - val_recall: 0.9225 - val_mean_squared_error: 0.0100 - val_cosine_similarity: 0.9414 - val_categorical_crossentropy: 0.2626
# Epoch 17/30
# 487/487 [==============================] - 751s 2s/step - loss: 0.1073 - accuracy: 0.9670 - categorical_accuracy: 0.9670 - precision: 0.9739 - recall: 0.9611 - mean_squared_error: 0.0050 - cosine_similarity: 0.9718 - categorical_crossentropy: 0.1073 - val_loss: 0.2478 - val_accuracy: 0.9385 - val_categorical_accuracy: 0.9385 - val_precision: 0.9547 - val_recall: 0.9276 - val_mean_squared_error: 0.0093 - val_cosine_similarity: 0.9458 - val_categorical_crossentropy: 0.2478
# Epoch 18/30
# 487/487 [==============================] - 753s 2s/step - loss: 0.0991 - accuracy: 0.9699 - categorical_accuracy: 0.9699 - precision: 0.9764 - recall: 0.9641 - mean_squared_error: 0.0046 - cosine_similarity: 0.9741 - categorical_crossentropy: 0.0991 - val_loss: 0.2654 - val_accuracy: 0.9387 - val_categorical_accuracy: 0.9387 - val_precision: 0.9506 - val_recall: 0.9327 - val_mean_squared_error: 0.0093 - val_cosine_similarity: 0.9460 - val_categorical_crossentropy: 0.2654
# Epoch 19/30
# 487/487 [==============================] - 756s 2s/step - loss: 0.0930 - accuracy: 0.9701 - categorical_accuracy: 0.9701 - precision: 0.9761 - recall: 0.9647 - mean_squared_error: 0.0045 - cosine_similarity: 0.9746 - categorical_crossentropy: 0.0930 - val_loss: 0.2671 - val_accuracy: 0.9384 - val_categorical_accuracy: 0.9384 - val_precision: 0.9485 - val_recall: 0.9317 - val_mean_squared_error: 0.0096 - val_cosine_similarity: 0.9447 - val_categorical_crossentropy: 0.2671
# Epoch 20/30
# 487/487 [==============================] - 772s 2s/step - loss: 0.0982 - accuracy: 0.9704 - categorical_accuracy: 0.9704 - precision: 0.9763 - recall: 0.9657 - mean_squared_error: 0.0045 - cosine_similarity: 0.9744 - categorical_crossentropy: 0.0982 - val_loss: 0.2694 - val_accuracy: 0.9355 - val_categorical_accuracy: 0.9355 - val_precision: 0.9474 - val_recall: 0.9278 - val_mean_squared_error: 0.0099 - val_cosine_similarity: 0.9432 - val_categorical_crossentropy: 0.2694
# Epoch 21/30
# 487/487 [==============================] - 786s 2s/step - loss: 0.0868 - accuracy: 0.9718 - categorical_accuracy: 0.9718 - precision: 0.9771 - recall: 0.9670 - mean_squared_error: 0.0042 - cosine_similarity: 0.9764 - categorical_crossentropy: 0.0868 - val_loss: 0.2526 - val_accuracy: 0.9437 - val_categorical_accuracy: 0.9437 - val_precision: 0.9529 - val_recall: 0.9377 - val_mean_squared_error: 0.0087 - val_cosine_similarity: 0.9501 - val_categorical_crossentropy: 0.2526
# Epoch 22/30
# 487/487 [==============================] - 795s 2s/step - loss: 0.0815 - accuracy: 0.9753 - categorical_accuracy: 0.9753 - precision: 0.9798 - recall: 0.9715 - mean_squared_error: 0.0038 - cosine_similarity: 0.9786 - categorical_crossentropy: 0.0815 - val_loss: 0.2590 - val_accuracy: 0.9433 - val_categorical_accuracy: 0.9433 - val_precision: 0.9540 - val_recall: 0.9380 - val_mean_squared_error: 0.0089 - val_cosine_similarity: 0.9491 - val_categorical_crossentropy: 0.2590
# Epoch 23/30
# 487/487 [==============================] - 760s 2s/step - loss: 0.0784 - accuracy: 0.9744 - categorical_accuracy: 0.9744 - precision: 0.9796 - recall: 0.9708 - mean_squared_error: 0.0038 - cosine_similarity: 0.9787 - categorical_crossentropy: 0.0784 - val_loss: 0.2658 - val_accuracy: 0.9437 - val_categorical_accuracy: 0.9437 - val_precision: 0.9521 - val_recall: 0.9389 - val_mean_squared_error: 0.0089 - val_cosine_similarity: 0.9495 - val_categorical_crossentropy: 0.2658
# Epoch 24/30
# 487/487 [==============================] - 758s 2s/step - loss: 0.0729 - accuracy: 0.9777 - categorical_accuracy: 0.9777 - precision: 0.9814 - recall: 0.9743 - mean_squared_error: 0.0035 - cosine_similarity: 0.9806 - categorical_crossentropy: 0.0729 - val_loss: 0.2645 - val_accuracy: 0.9419 - val_categorical_accuracy: 0.9419 - val_precision: 0.9520 - val_recall: 0.9362 - val_mean_squared_error: 0.0089 - val_cosine_similarity: 0.9490 - val_categorical_crossentropy: 0.2645
# Epoch 25/30
# 487/487 [==============================] - 751s 2s/step - loss: 0.0664 - accuracy: 0.9782 - categorical_accuracy: 0.9782 - precision: 0.9817 - recall: 0.9754 - mean_squared_error: 0.0033 - cosine_similarity: 0.9815 - categorical_crossentropy: 0.0664 - val_loss: 0.2914 - val_accuracy: 0.9390 - val_categorical_accuracy: 0.9390 - val_precision: 0.9487 - val_recall: 0.9327 - val_mean_squared_error: 0.0096 - val_cosine_similarity: 0.9454 - val_categorical_crossentropy: 0.2914
# Epoch 26/30
# 487/487 [==============================] - 750s 2s/step - loss: 0.0704 - accuracy: 0.9780 - categorical_accuracy: 0.9780 - precision: 0.9814 - recall: 0.9753 - mean_squared_error: 0.0034 - cosine_similarity: 0.9811 - categorical_crossentropy: 0.0704 - val_loss: 0.2679 - val_accuracy: 0.9432 - val_categorical_accuracy: 0.9432 - val_precision: 0.9512 - val_recall: 0.9376 - val_mean_squared_error: 0.0091 - val_cosine_similarity: 0.9488 - val_categorical_crossentropy: 0.2679
# Epoch 27/30
# 487/487 [==============================] - 765s 2s/step - loss: 0.0700 - accuracy: 0.9780 - categorical_accuracy: 0.9780 - precision: 0.9814 - recall: 0.9748 - mean_squared_error: 0.0034 - cosine_similarity: 0.9810 - categorical_crossentropy: 0.0700 - val_loss: 0.2856 - val_accuracy: 0.9402 - val_categorical_accuracy: 0.9402 - val_precision: 0.9488 - val_recall: 0.9356 - val_mean_squared_error: 0.0093 - val_cosine_similarity: 0.9469 - val_categorical_crossentropy: 0.2856
# Epoch 28/30
# 487/487 [==============================] - 791s 2s/step - loss: 0.0623 - accuracy: 0.9804 - categorical_accuracy: 0.9804 - precision: 0.9832 - recall: 0.9774 - mean_squared_error: 0.0031 - cosine_similarity: 0.9831 - categorical_crossentropy: 0.0623 - val_loss: 0.2916 - val_accuracy: 0.9416 - val_categorical_accuracy: 0.9416 - val_precision: 0.9479 - val_recall: 0.9378 - val_mean_squared_error: 0.0094 - val_cosine_similarity: 0.9472 - val_categorical_crossentropy: 0.2916
# Epoch 29/30
# 487/487 [==============================] - 761s 2s/step - loss: 0.0559 - accuracy: 0.9830 - categorical_accuracy: 0.9830 - precision: 0.9854 - recall: 0.9807 - mean_squared_error: 0.0027 - cosine_similarity: 0.9853 - categorical_crossentropy: 0.0559 - val_loss: 0.3390 - val_accuracy: 0.9298 - val_categorical_accuracy: 0.9298 - val_precision: 0.9390 - val_recall: 0.9247 - val_mean_squared_error: 0.0111 - val_cosine_similarity: 0.9367 - val_categorical_crossentropy: 0.3390
# Epoch 30/30
# 487/487 [==============================] - 781s 2s/step - loss: 0.0537 - accuracy: 0.9825 - categorical_accuracy: 0.9825 - precision: 0.9850 - recall: 0.9804 - mean_squared_error: 0.0027 - cosine_similarity: 0.9851 - categorical_crossentropy: 0.0537 - val_loss: 0.2845 - val_accuracy: 0.9400 - val_categorical_accuracy: 0.9400 - val_precision: 0.9484 - val_recall: 0.9365 - val_mean_squared_error: 0.0094 - val_cosine_similarity: 0.9468 - val_categorical_crossentropy: 0.2845
# Time taken to train the data: 22989.096 seconds

# %%
# Evaluate train and validation accuracies and losses

train_acc = history.history['accuracy']
train_cat_acc = history.history['categorical_accuracy']
train_precision = history.history['precision']
train_recall = history.history['recall']
train_mse = history.history['mean_squared_error']
train_cos_sim = history.history['cosine_similarity']
train_categorical_entrpy = history.history['categorical_crossentropy']

val_acc = history.history['val_accuracy']
val_cat_acc = history.history['val_categorical_accuracy']
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']
val_mse = history.history['val_mean_squared_error']
val_cos_sim = history.history['val_cosine_similarity']
val_categorical_entrpy = history.history['val_categorical_crossentropy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Visualize epochs vs. train and validation accuracies and losses

plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Epochs vs. Training and Validation Accuracy')
    
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()
plt.title('Epochs vs. Training and Validation Loss')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_precision, label='Training Precision')
plt.plot(val_precision, label='Validation Precision')
plt.legend()
plt.title('Epochs vs. Training and Validation Precision')

plt.subplot(1, 2, 2)
plt.plot(train_recall, label='Training Recall')
plt.plot(val_recall, label='Validation Recall')
plt.legend()
plt.title('Epochs vs. Training and Validation Recall')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_cat_acc, label='Training Categorical Accuracy')
plt.plot(val_cat_acc, label='Validation Categorical Accuracy')
plt.legend()
plt.title('Epochs vs. Training and Validation Categorical Accuracy')

plt.subplot(1, 2, 2)
plt.plot(train_mse, label='Training Mean Squared Error')
plt.plot(val_mse, label='Validation Mean Squared Error')
plt.legend()
plt.title('Epochs vs. Training and Validation Mean Squared Error')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_cos_sim, label='Training Cosine Similarity')
plt.plot(val_cos_sim, label='Validation Cosine Similarity')
plt.legend()
plt.title('Epochs vs. Training and Validation Cosine Similarity')

plt.subplot(1, 2, 2)
plt.plot(train_categorical_entrpy, label='Training Categorical Entropy')
plt.plot(val_categorical_entrpy, label='Validation Categorical Entropy')
plt.legend()
plt.title('Epochs vs. Training and Validation Categorical Entropy')

plt.show()

# %%
# Evaluate model on test data
test_loss, test_acc, test_cat_acc, test_precision, test_recall, test_mse, test_cos_sim, test_cat_entropy = model.evaluate(x=test_images, y=test_labels, verbose=0)

print('Test accuracy is: {:0.4f} \nTest loss is: {:0.4f} \nTest Categorical Accuracy is: {:0.4f} \nTest Precision is: {:0.4f} \nTest Recall is: {:0.4f} \nTest Mean Squared Error is: {:0.4f} \nTest Categorical Entopy is: {:0.4f}'.
      format(test_acc, test_loss, test_cat_acc, test_precision, test_recall, test_mse, test_cos_sim, test_cat_entropy))
# Out:
# Test accuracy is: 0.9432
# Test loss is: 0.2703
# Test Categorical Accuracy is: 0.9432
# Test Precision is: 0.9499
# Test Recall is: 0.9387
# Test Mean Squared Error is: 0.0089
# Test Categorical Entopy is: 0.9497

# %%
# Get predictions and apply inverse transformation to the labels (visualization and impacts)

y_pred = model.predict(X_train)

y_pred = lb.inverse_transform(y_pred, lb.classes_)
y_train = lb.inverse_transform(y_train, lb.classes_)

# %%
# Plot the confusion matrix

matrix = confusion_matrix(y_train, y_pred, labels=lb.classes_)

fig, ax = plt.subplots(figsize=(14, 12))
sns.heatmap(matrix, annot=True, cmap='Greens', fmt='d', ax=ax)
plt.title('Confusion Matrix for training dataset')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %%
# Ignore the errors in the plots

np.seterr(all='ignore')
# Out:
# {'divide': 'warn', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %%
# Get convolutional layers

layers = [model.get_layer('conv2d_1'), 
          model.get_layer('conv2d_2'), 
          model.get_layer('conv2d_3'),  
]

# %%
# Define a model which gives the outputs of the layers

layer_outputs = [layer.output for layer in layers]
activation_model = keras.models.Model(inputs=model.input, outputs=layer_outputs)

# %%
# Create a list with the names of the layers

layer_names = []
for layer in layers:
    layer_names.append(layer.name)

# %%
# Define a function which will plot the convolutional filters

def plot_convolutional_filters(img):
    
    img = np.expand_dims(img, axis=0)
    activations = activation_model.predict(img)
    images_per_row = 9
    
    for layer_name, layer_activation in zip(layer_names, activations): 
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols): 
            for row in range(images_per_row):
                channel_image = layer_activation[0,
                                                 :, :,
                                                 col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='plasma')

# %%
img = X_train[13529]
plt.imshow(img)
plt.show()

# %%
plot_convolutional_filters(img)
