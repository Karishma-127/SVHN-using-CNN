# %%
import tensorflow as tf
import numpy as np
import keras
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
from time import time
# %matplotlib inline

# %%
# Set random state

np.random.seed(20)

# %%
# Load the data

train_raw = loadmat('/content/sample_data/train_32x32.mat')
test_raw = loadmat('/content/sample_data/test_32x32.mat')

# %%
# Load images and labels

train_images = np.array(train_raw['X'])
test_images = np.array(test_raw['X'])

train_labels = train_raw['y']
test_labels = test_raw['y']

# %%
train_images = np.moveaxis(train_images, -1, 0)
test_images = np.moveaxis(test_images, -1, 0)

print(train_images.shape)
print(test_images.shape)
# Out:
# (73257, 32, 32, 3)
# (26032, 32, 32, 3)

# %%
# Plot a random image and its label

plt.imshow(train_images[13000])
plt.show()

print('Label: ', train_labels[13000])
# Out:
# Label:  [4]

# %%
# Convert train and test images into 'float64' type

train_images = train_images.astype('float64')
test_images = test_images.astype('float64')

# %%
# Convert train and test labels into 'int64' type

train_labels = train_labels.astype('int64')
test_labels = test_labels.astype('int64')

# %%
# Normalize the images data

print('Min: {}, Max: {}'.format(train_images.min(), train_images.max()))

train_images /= 255.0
test_images /= 255.0
# Out:
# Min: 0.0, Max: 255.0

# %%
# One-hot encoding of train and test labels

lb = LabelBinarizer()
train_labels = lb.fit_transform(train_labels)
test_labels = lb.fit_transform(test_labels)

# %%
# Split train data into train and validation sets

X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels,
                                                  test_size=0.15, random_state=22)

# %%
X_train = X_train[:40000,:,:,:]
y_train = y_train[:40000]

X_val = X_val[:10000,:,:,:]
y_val = y_val[:10000]

# %%
# Data augmentation (CNN Layer)

datagen = ImageDataGenerator(rotation_range=8,
                             zoom_range=[0.95, 1.05],
                             height_shift_range=0.10,
                             shear_range=0.15)

# %%
# Define actual model

keras.backend.clear_session()

model = keras.Sequential([
    keras.layers.Conv2D(32, (5, 5), padding='same', 
                           activation='relu',
                           input_shape=(32, 32, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(64, (5, 5), padding='same', 
                           activation='relu',
                           input_shape=(32, 32, 3)),
    keras.layers.BatchNormalization(),               
    keras.layers.MaxPooling2D((2, 2)),

    
    keras.layers.Conv2D(128, (5, 5), padding='same', 
                           activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(512, (5, 5), padding='same', 
                           activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Dropout(0.3),
    
    keras.layers.Flatten(),
    keras.layers.Dense(1000, activation='relu'),
    keras.layers.Dropout(0.4),    
    keras.layers.Dense(10,  activation='softmax')
])

early_stopping = keras.callbacks.EarlyStopping(monitor='loss', patience=8)
optimizer = keras.optimizers.Adam(lr=1e-3, amsgrad=True)
model_checkpoint = keras.callbacks.ModelCheckpoint(
                   '/content/sample_data/best_cnn.h5', 
                   save_best_only=True)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy', tf.keras.metrics.CategoricalAccuracy(), 
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       tf.keras.metrics.MeanSquaredError(),
                       tf.keras.metrics.CosineSimilarity(axis=1),
                       tf.keras.metrics.CategoricalCrossentropy()
                       ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1638912
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              2049000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 3,959,490
# Trainable params: 3,958,018
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
# Fit model in order to make predictions
start = time()
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=128),
                              epochs=30, validation_data=(X_val, y_val),
                              callbacks=[early_stopping, model_checkpoint])
end = time()
end = end - start
print('Time taken to train the data: {:.3f} seconds'.format(end))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/30
# 313/313 [==============================] - 526s 2s/step - loss: 2.6159 - accuracy: 0.2785 - categorical_accuracy: 0.2785 - precision: 0.4666 - recall: 0.1308 - mean_squared_error: 0.0865 - cosine_similarity: 0.3875 - categorical_crossentropy: 2.6159 - val_loss: 1.3112 - val_accuracy: 0.5911 - val_categorical_accuracy: 0.5911 - val_precision: 0.9131 - val_recall: 0.3079 - val_mean_squared_error: 0.0562 - val_cosine_similarity: 0.6364 - val_categorical_crossentropy: 1.3112
# Epoch 2/30
# 313/313 [==============================] - 523s 2s/step - loss: 0.6377 - accuracy: 0.8021 - categorical_accuracy: 0.8021 - precision: 0.8854 - recall: 0.7384 - mean_squared_error: 0.0278 - cosine_similarity: 0.8287 - categorical_crossentropy: 0.6377 - val_loss: 0.4767 - val_accuracy: 0.8541 - val_categorical_accuracy: 0.8541 - val_precision: 0.9107 - val_recall: 0.8145 - val_mean_squared_error: 0.0206 - val_cosine_similarity: 0.8738 - val_categorical_crossentropy: 0.4767
# Epoch 3/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.4509 - accuracy: 0.8649 - categorical_accuracy: 0.8649 - precision: 0.9197 - recall: 0.8241 - mean_squared_error: 0.0195 - cosine_similarity: 0.8827 - categorical_crossentropy: 0.4509 - val_loss: 0.3851 - val_accuracy: 0.8869 - val_categorical_accuracy: 0.8869 - val_precision: 0.9447 - val_recall: 0.8330 - val_mean_squared_error: 0.0166 - val_cosine_similarity: 0.9004 - val_categorical_crossentropy: 0.3851
# Epoch 4/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.3679 - accuracy: 0.8889 - categorical_accuracy: 0.8889 - precision: 0.9317 - recall: 0.8554 - mean_squared_error: 0.0161 - cosine_similarity: 0.9039 - categorical_crossentropy: 0.3679 - val_loss: 0.3286 - val_accuracy: 0.9016 - val_categorical_accuracy: 0.9016 - val_precision: 0.9448 - val_recall: 0.8712 - val_mean_squared_error: 0.0140 - val_cosine_similarity: 0.9166 - val_categorical_crossentropy: 0.3286
# Epoch 5/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.3218 - accuracy: 0.9044 - categorical_accuracy: 0.9044 - precision: 0.9405 - recall: 0.8768 - mean_squared_error: 0.0140 - cosine_similarity: 0.9166 - categorical_crossentropy: 0.3218 - val_loss: 0.3181 - val_accuracy: 0.9107 - val_categorical_accuracy: 0.9107 - val_precision: 0.9452 - val_recall: 0.8808 - val_mean_squared_error: 0.0132 - val_cosine_similarity: 0.9217 - val_categorical_crossentropy: 0.3181
# Epoch 6/30
# 313/313 [==============================] - 519s 2s/step - loss: 0.2785 - accuracy: 0.9138 - categorical_accuracy: 0.9138 - precision: 0.9450 - recall: 0.8886 - mean_squared_error: 0.0124 - cosine_similarity: 0.9262 - categorical_crossentropy: 0.2785 - val_loss: 0.2929 - val_accuracy: 0.9151 - val_categorical_accuracy: 0.9151 - val_precision: 0.9476 - val_recall: 0.8939 - val_mean_squared_error: 0.0122 - val_cosine_similarity: 0.9275 - val_categorical_crossentropy: 0.2929
# Epoch 7/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.2505 - accuracy: 0.9233 - categorical_accuracy: 0.9233 - precision: 0.9501 - recall: 0.9023 - mean_squared_error: 0.0112 - cosine_similarity: 0.9340 - categorical_crossentropy: 0.2505 - val_loss: 0.4109 - val_accuracy: 0.8840 - val_categorical_accuracy: 0.8840 - val_precision: 0.9207 - val_recall: 0.8591 - val_mean_squared_error: 0.0169 - val_cosine_similarity: 0.8989 - val_categorical_crossentropy: 0.4109
# Epoch 8/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.2511 - accuracy: 0.9244 - categorical_accuracy: 0.9244 - precision: 0.9498 - recall: 0.9037 - mean_squared_error: 0.0111 - cosine_similarity: 0.9348 - categorical_crossentropy: 0.2511 - val_loss: 0.3054 - val_accuracy: 0.9152 - val_categorical_accuracy: 0.9152 - val_precision: 0.9421 - val_recall: 0.8988 - val_mean_squared_error: 0.0123 - val_cosine_similarity: 0.9267 - val_categorical_crossentropy: 0.3054
# Epoch 9/30
# 313/313 [==============================] - 523s 2s/step - loss: 0.2169 - accuracy: 0.9327 - categorical_accuracy: 0.9327 - precision: 0.9538 - recall: 0.9177 - mean_squared_error: 0.0097 - cosine_similarity: 0.9431 - categorical_crossentropy: 0.2169 - val_loss: 0.2721 - val_accuracy: 0.9275 - val_categorical_accuracy: 0.9275 - val_precision: 0.9491 - val_recall: 0.9143 - val_mean_squared_error: 0.0108 - val_cosine_similarity: 0.9364 - val_categorical_crossentropy: 0.2721
# Epoch 10/30
# 313/313 [==============================] - 523s 2s/step - loss: 0.1948 - accuracy: 0.9404 - categorical_accuracy: 0.9404 - precision: 0.9588 - recall: 0.9270 - mean_squared_error: 0.0088 - cosine_similarity: 0.9490 - categorical_crossentropy: 0.1948 - val_loss: 0.2935 - val_accuracy: 0.9230 - val_categorical_accuracy: 0.9230 - val_precision: 0.9459 - val_recall: 0.9084 - val_mean_squared_error: 0.0113 - val_cosine_similarity: 0.9328 - val_categorical_crossentropy: 0.2935
# Epoch 11/30
# 313/313 [==============================] - 522s 2s/step - loss: 0.1824 - accuracy: 0.9444 - categorical_accuracy: 0.9444 - precision: 0.9605 - recall: 0.9299 - mean_squared_error: 0.0084 - cosine_similarity: 0.9516 - categorical_crossentropy: 0.1824 - val_loss: 0.2783 - val_accuracy: 0.9293 - val_categorical_accuracy: 0.9293 - val_precision: 0.9495 - val_recall: 0.9143 - val_mean_squared_error: 0.0106 - val_cosine_similarity: 0.9378 - val_categorical_crossentropy: 0.2783
# Epoch 12/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.1553 - accuracy: 0.9534 - categorical_accuracy: 0.9534 - precision: 0.9663 - recall: 0.9425 - mean_squared_error: 0.0071 - cosine_similarity: 0.9595 - categorical_crossentropy: 0.1553 - val_loss: 0.2704 - val_accuracy: 0.9320 - val_categorical_accuracy: 0.9320 - val_precision: 0.9501 - val_recall: 0.9208 - val_mean_squared_error: 0.0102 - val_cosine_similarity: 0.9401 - val_categorical_crossentropy: 0.2704
# Epoch 13/30
# 313/313 [==============================] - 519s 2s/step - loss: 0.1575 - accuracy: 0.9504 - categorical_accuracy: 0.9504 - precision: 0.9623 - recall: 0.9396 - mean_squared_error: 0.0073 - cosine_similarity: 0.9581 - categorical_crossentropy: 0.1575 - val_loss: 0.2761 - val_accuracy: 0.9296 - val_categorical_accuracy: 0.9296 - val_precision: 0.9495 - val_recall: 0.9158 - val_mean_squared_error: 0.0105 - val_cosine_similarity: 0.9385 - val_categorical_crossentropy: 0.2761
# Epoch 14/30
# 313/313 [==============================] - 519s 2s/step - loss: 0.1389 - accuracy: 0.9578 - categorical_accuracy: 0.9578 - precision: 0.9684 - recall: 0.9479 - mean_squared_error: 0.0064 - cosine_similarity: 0.9634 - categorical_crossentropy: 0.1389 - val_loss: 0.2779 - val_accuracy: 0.9312 - val_categorical_accuracy: 0.9312 - val_precision: 0.9477 - val_recall: 0.9236 - val_mean_squared_error: 0.0102 - val_cosine_similarity: 0.9404 - val_categorical_crossentropy: 0.2779
# Epoch 15/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.1277 - accuracy: 0.9614 - categorical_accuracy: 0.9614 - precision: 0.9702 - recall: 0.9534 - mean_squared_error: 0.0059 - cosine_similarity: 0.9665 - categorical_crossentropy: 0.1277 - val_loss: 0.3125 - val_accuracy: 0.9241 - val_categorical_accuracy: 0.9241 - val_precision: 0.9381 - val_recall: 0.9164 - val_mean_squared_error: 0.0114 - val_cosine_similarity: 0.9338 - val_categorical_crossentropy: 0.3125
# Epoch 16/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.1153 - accuracy: 0.9633 - categorical_accuracy: 0.9633 - precision: 0.9723 - recall: 0.9566 - mean_squared_error: 0.0055 - cosine_similarity: 0.9686 - categorical_crossentropy: 0.1153 - val_loss: 0.2975 - val_accuracy: 0.9225 - val_categorical_accuracy: 0.9225 - val_precision: 0.9395 - val_recall: 0.9116 - val_mean_squared_error: 0.0116 - val_cosine_similarity: 0.9325 - val_categorical_crossentropy: 0.2975
# Epoch 17/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.1083 - accuracy: 0.9659 - categorical_accuracy: 0.9659 - precision: 0.9734 - recall: 0.9595 - mean_squared_error: 0.0052 - cosine_similarity: 0.9707 - categorical_crossentropy: 0.1083 - val_loss: 0.2935 - val_accuracy: 0.9260 - val_categorical_accuracy: 0.9260 - val_precision: 0.9422 - val_recall: 0.9173 - val_mean_squared_error: 0.0109 - val_cosine_similarity: 0.9364 - val_categorical_crossentropy: 0.2935
# Epoch 18/30
# 313/313 [==============================] - 520s 2s/step - loss: 0.1084 - accuracy: 0.9648 - categorical_accuracy: 0.9648 - precision: 0.9722 - recall: 0.9595 - mean_squared_error: 0.0052 - cosine_similarity: 0.9707 - categorical_crossentropy: 0.1084 - val_loss: 0.3054 - val_accuracy: 0.9279 - val_categorical_accuracy: 0.9279 - val_precision: 0.9440 - val_recall: 0.9173 - val_mean_squared_error: 0.0111 - val_cosine_similarity: 0.9360 - val_categorical_crossentropy: 0.3054
# Epoch 19/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.0957 - accuracy: 0.9688 - categorical_accuracy: 0.9688 - precision: 0.9746 - recall: 0.9642 - mean_squared_error: 0.0047 - cosine_similarity: 0.9737 - categorical_crossentropy: 0.0957 - val_loss: 0.3035 - val_accuracy: 0.9286 - val_categorical_accuracy: 0.9286 - val_precision: 0.9415 - val_recall: 0.9214 - val_mean_squared_error: 0.0108 - val_cosine_similarity: 0.9375 - val_categorical_crossentropy: 0.3035
# Epoch 20/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.0910 - accuracy: 0.9706 - categorical_accuracy: 0.9706 - precision: 0.9767 - recall: 0.9658 - mean_squared_error: 0.0044 - cosine_similarity: 0.9754 - categorical_crossentropy: 0.0910 - val_loss: 0.2877 - val_accuracy: 0.9316 - val_categorical_accuracy: 0.9316 - val_precision: 0.9449 - val_recall: 0.9259 - val_mean_squared_error: 0.0103 - val_cosine_similarity: 0.9407 - val_categorical_crossentropy: 0.2877
# Epoch 21/30
# 313/313 [==============================] - 522s 2s/step - loss: 0.0862 - accuracy: 0.9736 - categorical_accuracy: 0.9736 - precision: 0.9784 - recall: 0.9700 - mean_squared_error: 0.0041 - cosine_similarity: 0.9771 - categorical_crossentropy: 0.0862 - val_loss: 0.2974 - val_accuracy: 0.9310 - val_categorical_accuracy: 0.9310 - val_precision: 0.9448 - val_recall: 0.9230 - val_mean_squared_error: 0.0105 - val_cosine_similarity: 0.9393 - val_categorical_crossentropy: 0.2974
# Epoch 22/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.0820 - accuracy: 0.9744 - categorical_accuracy: 0.9744 - precision: 0.9790 - recall: 0.9706 - mean_squared_error: 0.0039 - cosine_similarity: 0.9782 - categorical_crossentropy: 0.0820 - val_loss: 0.2914 - val_accuracy: 0.9364 - val_categorical_accuracy: 0.9364 - val_precision: 0.9462 - val_recall: 0.9298 - val_mean_squared_error: 0.0100 - val_cosine_similarity: 0.9427 - val_categorical_crossentropy: 0.2914
# Epoch 23/30
# 313/313 [==============================] - 522s 2s/step - loss: 0.0799 - accuracy: 0.9738 - categorical_accuracy: 0.9738 - precision: 0.9783 - recall: 0.9699 - mean_squared_error: 0.0039 - cosine_similarity: 0.9781 - categorical_crossentropy: 0.0799 - val_loss: 0.3229 - val_accuracy: 0.9281 - val_categorical_accuracy: 0.9281 - val_precision: 0.9399 - val_recall: 0.9224 - val_mean_squared_error: 0.0110 - val_cosine_similarity: 0.9366 - val_categorical_crossentropy: 0.3229
# Epoch 24/30
# 313/313 [==============================] - 522s 2s/step - loss: 0.0757 - accuracy: 0.9758 - categorical_accuracy: 0.9758 - precision: 0.9793 - recall: 0.9723 - mean_squared_error: 0.0038 - cosine_similarity: 0.9789 - categorical_crossentropy: 0.0757 - val_loss: 0.3204 - val_accuracy: 0.9331 - val_categorical_accuracy: 0.9331 - val_precision: 0.9439 - val_recall: 0.9286 - val_mean_squared_error: 0.0104 - val_cosine_similarity: 0.9404 - val_categorical_crossentropy: 0.3204
# Epoch 25/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.0797 - accuracy: 0.9745 - categorical_accuracy: 0.9745 - precision: 0.9782 - recall: 0.9711 - mean_squared_error: 0.0039 - cosine_similarity: 0.9780 - categorical_crossentropy: 0.0797 - val_loss: 0.3081 - val_accuracy: 0.9338 - val_categorical_accuracy: 0.9338 - val_precision: 0.9426 - val_recall: 0.9294 - val_mean_squared_error: 0.0102 - val_cosine_similarity: 0.9416 - val_categorical_crossentropy: 0.3081
# Epoch 26/30
# 313/313 [==============================] - 521s 2s/step - loss: 0.0646 - accuracy: 0.9785 - categorical_accuracy: 0.9785 - precision: 0.9817 - recall: 0.9763 - mean_squared_error: 0.0032 - cosine_similarity: 0.9822 - categorical_crossentropy: 0.0646 - val_loss: 0.3050 - val_accuracy: 0.9357 - val_categorical_accuracy: 0.9357 - val_precision: 0.9446 - val_recall: 0.9300 - val_mean_squared_error: 0.0099 - val_cosine_similarity: 0.9435 - val_categorical_crossentropy: 0.3050
# Epoch 27/30
# 313/313 [==============================] - 524s 2s/step - loss: 0.0682 - accuracy: 0.9790 - categorical_accuracy: 0.9790 - precision: 0.9815 - recall: 0.9755 - mean_squared_error: 0.0033 - cosine_similarity: 0.9819 - categorical_crossentropy: 0.0682 - val_loss: 0.3207 - val_accuracy: 0.9356 - val_categorical_accuracy: 0.9356 - val_precision: 0.9454 - val_recall: 0.9307 - val_mean_squared_error: 0.0101 - val_cosine_similarity: 0.9422 - val_categorical_crossentropy: 0.3207
# Epoch 28/30
# 313/313 [==============================] - 524s 2s/step - loss: 0.0622 - accuracy: 0.9797 - categorical_accuracy: 0.9797 - precision: 0.9822 - recall: 0.9778 - mean_squared_error: 0.0031 - cosine_similarity: 0.9828 - categorical_crossentropy: 0.0622 - val_loss: 0.3397 - val_accuracy: 0.9272 - val_categorical_accuracy: 0.9272 - val_precision: 0.9386 - val_recall: 0.9213 - val_mean_squared_error: 0.0111 - val_cosine_similarity: 0.9364 - val_categorical_crossentropy: 0.3397
# Epoch 29/30
# 313/313 [==============================] - 524s 2s/step - loss: 0.0543 - accuracy: 0.9818 - categorical_accuracy: 0.9818 - precision: 0.9845 - recall: 0.9795 - mean_squared_error: 0.0027 - cosine_similarity: 0.9849 - categorical_crossentropy: 0.0543 - val_loss: 0.3265 - val_accuracy: 0.9328 - val_categorical_accuracy: 0.9328 - val_precision: 0.9441 - val_recall: 0.9292 - val_mean_squared_error: 0.0104 - val_cosine_similarity: 0.9404 - val_categorical_crossentropy: 0.3265
# Epoch 30/30
# 313/313 [==============================] - 525s 2s/step - loss: 0.0529 - accuracy: 0.9828 - categorical_accuracy: 0.9828 - precision: 0.9850 - recall: 0.9804 - mean_squared_error: 0.0026 - cosine_similarity: 0.9853 - categorical_crossentropy: 0.0529 - val_loss: 0.3424 - val_accuracy: 0.9284 - val_categorical_accuracy: 0.9284 - val_precision: 0.9416 - val_recall: 0.9213 - val_mean_squared_error: 0.0109 - val_cosine_similarity: 0.9365 - val_categorical_crossentropy: 0.3424
# Time taken to train the data: 15646.042 seconds

# %%
# Evaluate train and validation accuracies and losses

train_acc = history.history['accuracy']
train_cat_acc = history.history['categorical_accuracy']
train_precision = history.history['precision']
train_recall = history.history['recall']
train_mse = history.history['mean_squared_error']
train_cos_sim = history.history['cosine_similarity']
train_categorical_entrpy = history.history['categorical_crossentropy']

val_acc = history.history['val_accuracy']
val_cat_acc = history.history['val_categorical_accuracy']
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']
val_mse = history.history['val_mean_squared_error']
val_cos_sim = history.history['val_cosine_similarity']
val_categorical_entrpy = history.history['val_categorical_crossentropy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Visualize epochs vs. train and validation accuracies and losses

plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.title('Epochs vs. Training and Validation Accuracy')
    
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend()
plt.title('Epochs vs. Training and Validation Loss')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_precision, label='Training Precision')
plt.plot(val_precision, label='Validation Precision')
plt.legend()
plt.title('Epochs vs. Training and Validation Precision')

plt.subplot(1, 2, 2)
plt.plot(train_recall, label='Training Recall')
plt.plot(val_recall, label='Validation Recall')
plt.legend()
plt.title('Epochs vs. Training and Validation Recall')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_cat_acc, label='Training Categorical Accuracy')
plt.plot(val_cat_acc, label='Validation Categorical Accuracy')
plt.legend()
plt.title('Epochs vs. Training and Validation Categorical Accuracy')

plt.subplot(1, 2, 2)
plt.plot(train_mse, label='Training Mean Squared Error')
plt.plot(val_mse, label='Validation Mean Squared Error')
plt.legend()
plt.title('Epochs vs. Training and Validation Mean Squared Error')

plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.plot(train_cos_sim, label='Training Cosine Similarity')
plt.plot(val_cos_sim, label='Validation Cosine Similarity')
plt.legend()
plt.title('Epochs vs. Training and Validation Cosine Similarity')

plt.subplot(1, 2, 2)
plt.plot(train_categorical_entrpy, label='Training Categorical Entropy')
plt.plot(val_categorical_entrpy, label='Validation Categorical Entropy')
plt.legend()
plt.title('Epochs vs. Training and Validation Categorical Entropy')

plt.show()

# %%
# Evaluate model on test data
test_loss, test_acc, test_cat_acc, test_precision, test_recall, test_mse, test_cos_sim, test_cat_entropy = model.evaluate(x=test_images, y=test_labels, verbose=0)

print('Test accuracy is: {:0.4f} \nTest loss is: {:0.4f} \nTest Categorical Accuracy is: {:0.4f} \nTest Precision is: {:0.4f} \nTest Recall is: {:0.4f} \nTest Mean Squared Error is: {:0.4f} \nTest Categorical Entopy is: {:0.4f}'.
      format(test_acc, test_loss, test_cat_acc, test_precision, test_recall, test_mse, test_cos_sim, test_cat_entropy))
# Out:
# Test accuracy is: 0.9263
# Test loss is: 0.3498
# Test Categorical Accuracy is: 0.9263
# Test Precision is: 0.9364
# Test Recall is: 0.9213
# Test Mean Squared Error is: 0.0115
# Test Categorical Entopy is: 0.9348

# %%
# Get predictions and apply inverse transformation to the labels (visualization and impacts)

y_pred = model.predict(X_train)

y_pred = lb.inverse_transform(y_pred, lb.classes_)
y_train = lb.inverse_transform(y_train, lb.classes_)

# %%
# Plot the confusion matrix

matrix = confusion_matrix(y_train, y_pred, labels=lb.classes_)

fig, ax = plt.subplots(figsize=(14, 12))
sns.heatmap(matrix, annot=True, cmap='Greens', fmt='d', ax=ax)
plt.title('Confusion Matrix for training dataset')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# %%
# Ignore the errors in the plots

np.seterr(all='ignore')
# Out:
# {'divide': 'warn', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %%
# Get convolutional layers

layers = [model.get_layer('conv2d_1'), 
          model.get_layer('conv2d_2'), 
          model.get_layer('conv2d_3'),  
]

# %%
# Define a model which gives the outputs of the layers

layer_outputs = [layer.output for layer in layers]
activation_model = keras.models.Model(inputs=model.input, outputs=layer_outputs)

# %%
# Create a list with the names of the layers

layer_names = []
for layer in layers:
    layer_names.append(layer.name)

# %%
# Define a function which will plot the convolutional filters

def plot_convolutional_filters(img):
    
    img = np.expand_dims(img, axis=0)
    activations = activation_model.predict(img)
    images_per_row = 9
    
    for layer_name, layer_activation in zip(layer_names, activations): 
        n_features = layer_activation.shape[-1]
        size = layer_activation.shape[1]
        n_cols = n_features // images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))
        for col in range(n_cols): 
            for row in range(images_per_row):
                channel_image = layer_activation[0,
                                                 :, :,
                                                 col * images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                display_grid[col * size : (col + 1) * size,
                             row * size : (row + 1) * size] = channel_image
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='plasma')

# %%
img = X_train[13529]
plt.imshow(img)
plt.show()

# %%
plot_convolutional_filters(img)
